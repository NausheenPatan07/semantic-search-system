# %%
import os
import pandas as pd

# %%
data_path = "data/20_newsgroups"

# %%
documents = []
labels = []

for category in os.listdir(data_path):
    
    category_path = os.path.join(data_path, category)
    
    if os.path.isdir(category_path):
        
        for file in os.listdir(category_path):
            
            file_path = os.path.join(category_path, file)
            
            with open(file_path, "r", encoding="latin1") as f:
                
                documents.append(f.read())
                labels.append(category)

print("Total documents:", len(documents))
print("Total categories:", len(set(labels)))
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[18], line 14
#      10 for file in os.listdir(category_path):
#      12     file_path = os.path.join(category_path, file)
# ---> 14     with open(file_path, "r", encoding="latin1") as f:
#      16         documents.append(f.read())
#      17         labels.append(category)
#
# File ~\semantic-search-system\venv\Lib\site-packages\IPython\core\interactiveshell.py:346, in _modified_open(file, *args, **kwargs)
#     339 if file in {0, 1, 2}:
#     340     raise ValueError(
#     341         f"IPython won't let you open fd={file} by default "
#     342         "as it is likely to crash IPython. If you know what you are doing, "
#     343         "you can use builtins' open."
#     344     )
# --> 346 return io_open(file, *args, **kwargs)
#
# PermissionError: [Errno 13] Permission denied: 'data/20_newsgroups\\20_newsgroups\\alt.atheism'

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\naush\\semantic-search-system'

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints', 'data', 'dataset_loading.ipynb', 'venv']

# %%
os.listdir("data")
# Out:
# ['20newsgroups.data.html',
#  '20newsgroups.html',
#  '20_newsgroups.tar.gz',
#  'mini_newsgroups',
#  'mini_newsgroups.tar.gz',
#  'venv']

# %%
import tarfile

tar = tarfile.open("20_newsgroups.tar.gz", "r:gz")
tar.extractall()
tar.close()

print("Extraction completed")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 3
#       1 import tarfile
# ----> 3 tar = tarfile.open("20_newsgroups.tar.gz", "r:gz")
#       4 tar.extractall()
#       5 tar.close()
#
# File C:\Program Files\Python312\Lib\tarfile.py:1821, in TarFile.open(cls, name, mode, fileobj, bufsize, **kwargs)
#    1819     else:
#    1820         raise CompressionError("unknown compression type %r" % comptype)
# -> 1821     return func(name, filemode, fileobj, **kwargs)
#    1823 elif "|" in mode:
#    1824     filemode, comptype = mode.split("|", 1)
#
# File C:\Program Files\Python312\Lib\tarfile.py:1869, in TarFile.gzopen(cls, name, mode, fileobj, compresslevel, **kwargs)
#    1866     raise CompressionError("gzip module is not available") from None
#    1868 try:
# -> 1869     fileobj = GzipFile(name, mode + "b", compresslevel, fileobj)
#    1870 except OSError as e:
#    1871     if fileobj is not None and mode == 'r':
#
# File C:\Program Files\Python312\Lib\gzip.py:192, in GzipFile.__init__(self, filename, mode, compresslevel, fileobj, mtime)
#     190     mode += 'b'
#     191 if fileobj is None:
# --> 192     fileobj = self.myfileobj = builtins.open(filename, mode or 'rb')
#     193 if filename is None:
#     194     filename = getattr(fileobj, 'name', '')
#
# FileNotFoundError: [Errno 2] No such file or directory: '20_newsgroups.tar.gz'

# %%
import tarfile

tar = tarfile.open("mini_newsgroups.tar.gz", "r:gz")
tar.extractall()
tar.close()

print("Extraction completed")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 3
#       1 import tarfile
# ----> 3 tar = tarfile.open("mini_newsgroups.tar.gz", "r:gz")
#       4 tar.extractall()
#       5 tar.close()
#
# File C:\Program Files\Python312\Lib\tarfile.py:1821, in TarFile.open(cls, name, mode, fileobj, bufsize, **kwargs)
#    1819     else:
#    1820         raise CompressionError("unknown compression type %r" % comptype)
# -> 1821     return func(name, filemode, fileobj, **kwargs)
#    1823 elif "|" in mode:
#    1824     filemode, comptype = mode.split("|", 1)
#
# File C:\Program Files\Python312\Lib\tarfile.py:1869, in TarFile.gzopen(cls, name, mode, fileobj, compresslevel, **kwargs)
#    1866     raise CompressionError("gzip module is not available") from None
#    1868 try:
# -> 1869     fileobj = GzipFile(name, mode + "b", compresslevel, fileobj)
#    1870 except OSError as e:
#    1871     if fileobj is not None and mode == 'r':
#
# File C:\Program Files\Python312\Lib\gzip.py:192, in GzipFile.__init__(self, filename, mode, compresslevel, fileobj, mtime)
#     190     mode += 'b'
#     191 if fileobj is None:
# --> 192     fileobj = self.myfileobj = builtins.open(filename, mode or 'rb')
#     193 if filename is None:
#     194     filename = getattr(fileobj, 'name', '')
#
# FileNotFoundError: [Errno 2] No such file or directory: 'mini_newsgroups.tar.gz'

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints', 'data', 'dataset_loading.ipynb', 'venv']

# %%
import tarfile

file_path = "./20_newsgroups.tar.gz"

with tarfile.open(file_path, "r:gz") as tar:
    tar.extractall()

print("Extraction completed")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[10], line 5
#       1 import tarfile
#       3 file_path = "./20_newsgroups.tar.gz"
# ----> 5 with tarfile.open(file_path, "r:gz") as tar:
#       6     tar.extractall()
#       8 print("Extraction completed")
#
# File C:\Program Files\Python312\Lib\tarfile.py:1821, in TarFile.open(cls, name, mode, fileobj, bufsize, **kwargs)
#    1819     else:
#    1820         raise CompressionError("unknown compression type %r" % comptype)
# -> 1821     return func(name, filemode, fileobj, **kwargs)
#    1823 elif "|" in mode:
#    1824     filemode, comptype = mode.split("|", 1)
#
# File C:\Program Files\Python312\Lib\tarfile.py:1869, in TarFile.gzopen(cls, name, mode, fileobj, compresslevel, **kwargs)
#    1866     raise CompressionError("gzip module is not available") from None
#    1868 try:
# -> 1869     fileobj = GzipFile(name, mode + "b", compresslevel, fileobj)
#    1870 except OSError as e:
#    1871     if fileobj is not None and mode == 'r':
#
# File C:\Program Files\Python312\Lib\gzip.py:192, in GzipFile.__init__(self, filename, mode, compresslevel, fileobj, mtime)
#     190     mode += 'b'
#     191 if fileobj is None:
# --> 192     fileobj = self.myfileobj = builtins.open(filename, mode or 'rb')
#     193 if filename is None:
#     194     filename = getattr(fileobj, 'name', '')
#
# FileNotFoundError: [Errno 2] No such file or directory: './20_newsgroups.tar.gz'

# %%
import os
os.listdir()
# Out:
# ['.ipynb_checkpoints', 'data', 'dataset_loading.ipynb', 'venv']

# %%
import os
os.listdir("data")
# Out:
# ['20newsgroups.data.html',
#  '20newsgroups.html',
#  '20_newsgroups',
#  '20_newsgroups.tar.gz',
#  'mini_newsgroups',
#  'mini_newsgroups.tar.gz',
#  'venv']

# %%
data_path = "data/20_newsgroups"

# %%
import os

documents = []
labels = []

for category in os.listdir(data_path):

    category_path = os.path.join(data_path, category)

    if os.path.isdir(category_path):

        for file in os.listdir(category_path):

            file_path = os.path.join(category_path, file)

            with open(file_path, "r", encoding="latin1") as f:
                documents.append(f.read())
                labels.append(category)

print("Total documents:", len(documents))
print("Total categories:", len(set(labels)))
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[14], line 16
#      12 for file in os.listdir(category_path):
#      14     file_path = os.path.join(category_path, file)
# ---> 16     with open(file_path, "r", encoding="latin1") as f:
#      17         documents.append(f.read())
#      18         labels.append(category)
#
# File ~\semantic-search-system\venv\Lib\site-packages\IPython\core\interactiveshell.py:346, in _modified_open(file, *args, **kwargs)
#     339 if file in {0, 1, 2}:
#     340     raise ValueError(
#     341         f"IPython won't let you open fd={file} by default "
#     342         "as it is likely to crash IPython. If you know what you are doing, "
#     343         "you can use builtins' open."
#     344     )
# --> 346 return io_open(file, *args, **kwargs)
#
# PermissionError: [Errno 13] Permission denied: 'data/20_newsgroups\\20_newsgroups\\alt.atheism'

# %%
data_path = "data/20_newsgroups/20_newsgroups"

# %%
import os

data_path = "data/20_newsgroups/20_newsgroups"

documents = []
labels = []

for category in os.listdir(data_path):

    category_path = os.path.join(data_path, category)

    if os.path.isdir(category_path):

        for file in os.listdir(category_path):

            file_path = os.path.join(category_path, file)

            with open(file_path, "r", encoding="latin1") as f:
                documents.append(f.read())
                labels.append(category)

print("Total documents:", len(documents))
print("Total categories:", len(set(labels)))
# Out:
# Total documents: 19997
# Total categories: 20

# %%
import pandas as pd

df = pd.DataFrame({
    "text": documents,
    "category": labels
})

df.head()
# Out:
#                                                 text     category
# 0  Xref: cantaloupe.srv.cs.cmu.edu alt.atheism:49...  alt.atheism
# 1  Xref: cantaloupe.srv.cs.cmu.edu alt.atheism:51...  alt.atheism
# 2  Newsgroups: alt.atheism\nPath: cantaloupe.srv....  alt.atheism
# 3  Xref: cantaloupe.srv.cs.cmu.edu alt.atheism:51...  alt.atheism
# 4  Xref: cantaloupe.srv.cs.cmu.edu alt.atheism:51...  alt.atheism

# %%
import re

# %%
def clean_text(text):
    
    # Remove email headers (everything before the first blank line)
    text = re.split(r"\n\n", text, maxsplit=1)[-1]

    # Remove email addresses
    text = re.sub(r"\S+@\S+", "", text)

    # Remove special characters
    text = re.sub(r"[^a-zA-Z0-9\s]", " ", text)

    # Remove extra spaces
    text = re.sub(r"\s+", " ", text)

    return text.strip()

# %%
df["clean_text"] = df["text"].apply(clean_text)

# %%
print("BEFORE CLEANING:\n")
print(df["text"][0][:500])

print("\n\nAFTER CLEANING:\n")
print(df["clean_text"][0][:500])
# Out:
# BEFORE CLEANING:
#
# Xref: cantaloupe.srv.cs.cmu.edu alt.atheism:49960 alt.atheism.moderated:713 news.answers:7054 alt.answers:126
# Path: cantaloupe.srv.cs.cmu.edu!crabapple.srv.cs.cmu.edu!bb3.andrew.cmu.edu!news.sei.cmu.edu!cis.ohio-state.edu!magnus.acs.ohio-state.edu!usenet.ins.cwru.edu!agate!spool.mu.edu!uunet!pipex!ibmpcug!mantis!mathew
# From: mathew <mathew@mantis.co.uk>
# Newsgroups: alt.atheism,alt.atheism.moderated,news.answers,alt.answers
# Subject: Alt.Atheism FAQ: Atheist Resources
# Summary: Books, addresses, mu
#
#
# AFTER CLEANING:
#
# Archive name atheism resources Alt atheism archive name resources Last modified 11 December 1992 Version 1 0 Atheist Resources Addresses of Atheist Organizations USA FREEDOM FROM RELIGION FOUNDATION Darwin fish bumper stickers and assorted other atheist paraphernalia are available from the Freedom From Religion Foundation in the US Write to FFRF P O Box 750 Madison WI 53701 Telephone 608 256 8900 EVOLUTION DESIGNS Evolution Designs sell the Darwin fish It s a fish symbol like the ones Christians

# %%
df.shape
# Out:
# (19997, 3)

# %%
from sentence_transformers import SentenceTransformer

# %%
model = SentenceTransformer("all-MiniLM-L6-v2")
# Out:
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.

# %%
embeddings = model.encode(
    df["clean_text"].tolist(),
    show_progress_bar=True
)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\semantic-search-system\venv\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7676, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'clean_text'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[35], line 2
#       1 embeddings = model.encode(
# ----> 2     df["clean_text"].tolist(),
#       3     show_progress_bar=True
#       4 )
#
# File ~\semantic-search-system\venv\Lib\site-packages\pandas\core\frame.py:4378, in DataFrame.__getitem__(self, key)
#    4376 if self.columns.nlevels > 1:
#    4377     return self._getitem_multilevel(key)
# -> 4378 indexer = self.columns.get_loc(key)
#    4379 if is_integer(indexer):
#    4380     indexer = [indexer]
#
# File ~\semantic-search-system\venv\Lib\site-packages\pandas\core\indexes\base.py:3648, in Index.get_loc(self, key)
#    3643     if isinstance(casted_key, slice) or (
#    3644         isinstance(casted_key, abc.Iterable)
#    3645         and any(isinstance(x, slice) for x in casted_key)
#    3646     ):
#    3647         raise InvalidIndexError(key) from err
# -> 3648     raise KeyError(key) from err
#    3649 except TypeError:
#    3650     # If we have a listlike key, _check_indexing_error will raise
#    3651     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3652     #  the TypeError.
#    3653     self._check_indexing_error(key)
#
# KeyError: 'clean_text'

# %%
import numpy as np

embeddings = np.array(embeddings)

print("Embedding shape:", embeddings.shape)
# Out:
# Embedding shape: (19997, 384)

# %%
df["embedding"] = embeddings.tolist()

# text
# category
# clean_text
# embedding

# Sentence Transformers convert documents into dense vector
# representations that capture semantic meaning. These embeddings
# allow efficient similarity search and clustering in vector space.

# %%
# Step 7 — Build the Vector Database (FAISS)
import faiss
import numpy as np

# %%
embedding_matrix = np.array(embeddings).astype("float32")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 embedding_matrix = np.array(embeddings).astype("float32")
#
# NameError: name 'embeddings' is not defined

# %%
embedding_matrix.shape
# Out:
# (19997, 384)

# %%
# Create FAISS Index
# IndexFlatL2 → exact similarity search using Euclidean distance
# dimension → embedding size (384)

dimension = embedding_matrix.shape[1]

index = faiss.IndexFlatL2(dimension)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 5
#       1 # Create FAISS Index
#       2 # IndexFlatL2 → exact similarity search using Euclidean distance
#       3 # dimension → embedding size (384)
# ----> 5 dimension = embedding_matrix.shape[1]
#       7 index = faiss.IndexFlatL2(dimension)
#
# NameError: name 'embedding_matrix' is not defined

# %%
index.add(embedding_matrix)

# %%
# Add Vectors to FAISS
print("Total vectors in index:", index.ntotal)
# Out:
# Total vectors in index: 19997

# %%
query = "space mission launch satellite"

query_embedding = model.encode([query]).astype("float32")

k = 5

distances, indices = index.search(query_embedding, k)

# %%
# 7.6 Display Results
# FAISS is used as a vector index to efficiently perform
# nearest-neighbour search over document embeddings.
# This enables semantic retrieval based on meaning rather
# than keyword matching.

for i in indices[0]:
    print("Category:", df.iloc[i]["category"])
    print(df.iloc[i]["clean_text"][:200])
    print("-----")
# Out:
# Category: sci.space
# Date Tue 6 Apr 1993 15 40 47 GMT I need as much information about Cosmos 2238 and its rocket fragment 1993 018B as possible Both its purpose launch date location in short EVERYTHING Can you help Tony
# -----
# Category: sci.space
# In article Henry Spencer writes In article David M Palmer writes orbiting billboard I would just like to point out that it is much easier to place an object at orbital altitude than it is to place it
# -----
# Category: sci.space
# I can tell you that when AMSAT launched some birds along a Spot satellite French that during installation of some instruments on Spot 2 there heavily armed legionaires who had a take no prisoners look
# -----
# Category: sci.space
# Bill Higgins Beam Jockey writes In article writes COMMERCIAL SPACE NEWS SPACE TECHNOLOGY INVESTOR NUMBER 22 Other commercial launch site ventures including those at Woomera Poker Flat Cape York White
# -----
# Category: sci.space
# ARIANESPACE FLIGHT 56 Flight V 56 was originally intended to carry the Hughes HS 601 series Galaxy IV satellite but the payload was withdrawn just prior to flight The 56th Ariane launch is now schedul
# -----

# %%
# Step 8 — Fuzzy Clustering of Documents

# !pip install scikit-fuzzy
# Out:
# Requirement already satisfied: scikit-fuzzy in .\venv\Lib\site-packages (0.5.0)

# %%
import skfuzzy as fuzz

# %%
# 8.3 Prepare Data for Clustering
# Fuzzy C-Means expects data in feature × samples format.We must transpose them.

X = embedding_matrix.T

# %%
print(X.shape)
# Out:
# (384, 19997)

# %%
n_clusters = 12

# %%
cntr, u, u0, d, jm, p, fpc = fuzz.cluster.cmeans(
    X,
    c=n_clusters,
    m=2,
    error=0.005,
    maxiter=1000,
    init=None
)

# %%
u
# Out:
# array([[0.08333381, 0.08333406, 0.08333373, ..., 0.08333405, 0.08333425,
#         0.08333369],
#        [0.08333321, 0.08333313, 0.08333323, ..., 0.08333313, 0.08333305,
#         0.08333325],
#        [0.08333313, 0.08333304, 0.08333316, ..., 0.08333302, 0.0833329 ,
#         0.08333313],
#        ...,
#        [0.08333299, 0.0833328 , 0.08333309, ..., 0.08333285, 0.08333274,
#         0.08333316],
#        [0.0833323 , 0.08333185, 0.08333241, ..., 0.08333179, 0.08333172,
#         0.08333262],
#        [0.08333406, 0.08333443, 0.08333389, ..., 0.08333439, 0.08333464,
#         0.08333379]], shape=(12, 19997))

# %%
(n_clusters, num_documents)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 (n_clusters, num_documents)
#
# NameError: name 'num_documents' is not defined

# %%
print(u.shape)
# Out:
# (12, 19997)

# %%
# 8.7 Assign Dominant Cluster

cluster_labels = np.argmax(u, axis=0)

# %%
cluster_labels[:10]
# Out:
# array([6, 6, 6, 6, 6, 6, 6, 6, 6, 6])

# %%
# 8.8 Add Cluster Labels to DataFrame

df["cluster"] = cluster_labels

# %%
df.head()
# Out:
#                                                 text     category  \
# 0  Xref: cantaloupe.srv.cs.cmu.edu alt.atheism:49...  alt.atheism
# 1  Xref: cantaloupe.srv.cs.cmu.edu alt.atheism:51...  alt.atheism
# 2  Newsgroups: alt.atheism\nPath: cantaloupe.srv....  alt.atheism
# 3  Xref: cantaloupe.srv.cs.cmu.edu alt.atheism:51...  alt.atheism
# 4  Xref: cantaloupe.srv.cs.cmu.edu alt.atheism:51...  alt.atheism
#
#                                           clean_text  \
# 0  Archive name atheism resources Alt atheism arc...
# 1  Archive name atheism introduction Alt atheism ...
# 2  In article Charley Wingate writes Well John ha...
# 3  until kings become philosophers or philosopher...
# 4  In article Bob McGwier writes 1 HOWEVER I hate...
#
#                                            embedding  cluster
# 0  [-0.0285569429397583, 0.016917048022150993, -0...        6
# 1  [-0.027238793671131134, -0.04237806797027588, ...        6
# 2  [-0.09503985196352005, -0.004863628186285496, ...        6
# 3  [-0.033383529633283615, 0.044307440519332886, ...        6
# 4  [-0.02208806946873665, 0.06549318879842758, -0...        6

# %%
df["cluster"].value_counts()
# Out:
# cluster
# 6     9867
# 10    8027
# 7     1651
# 3      254
# 0      113
# 11      39
# 2       18
# 4       14
# 9       12
# 5        1
# 1        1
# Name: count, dtype: int64

# %%
import numpy as np
from sentence_transformers import SentenceTransformer

# %%
# Fuzzy C-Means clustering is applied to the document embeddings
# to discover latent semantic groups within the dataset.

# Unlike hard clustering algorithms such as K-Means,
# Fuzzy C-Means assigns membership probabilities to each
# document across clusters, allowing documents to belong
# to multiple semantic themes simultaneously.


semantic_cache = {}

# %%
{
  query_embedding : search_results
}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 {
# ----> 2   query_embedding : search_results
#       3 }
#
# NameError: name 'query_embedding' is not defined

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
# 9.3 Build Cache Search Function

# Create a function to check if a similar query already exists.

def check_cache(query_embedding, threshold=0.90):

    for cached_query, cached_result in semantic_cache.items():

        similarity = cosine_similarity(
            [query_embedding],
            [cached_query]
        )[0][0]

        if similarity > threshold:
            return cached_result

    return None

# %%
from sentence_transformers import SentenceTransformer

model = SentenceTransformer("all-MiniLM-L6-v2")
# Out:
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.

# %%
model = SentenceTransformer("all-MiniLM-L6-v2")
# Out:
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.

# %%
print(model)
# Out:
# SentenceTransformer(
#   (0): Transformer({'max_seq_length': 256, 'do_lower_case': False, 'architecture': 'BertModel'})
#   (1): Pooling({'word_embedding_dimension': 384, 'pooling_mode_cls_token': False, 'pooling_mode_mean_tokens': True, 'pooling_mode_max_tokens': False, 'pooling_mode_mean_sqrt_len_tokens': False, 'pooling_mode_weightedmean_tokens': False, 'pooling_mode_lasttoken': False, 'include_prompt': True})
#   (2): Normalize()
# )

# %%
model.encode(["space shuttle mission"])
# Out:
# array([[ 4.80819214e-03, -1.68409804e-03, -3.79324332e-02,
#          1.45229530e-02, -7.44499862e-02, -1.62368976e-02,
#          7.86334053e-02, -2.18448155e-02,  5.48836589e-03,
#         -1.33092189e-02, -2.20028367e-02,  2.02864539e-02,
#          1.31824063e-02, -1.10626984e-02, -2.69972831e-02,
#         -1.24883000e-02,  6.51932359e-02, -6.81476714e-03,
#         -4.14763875e-02, -6.11192323e-02,  3.92902817e-04,
#          1.22798001e-02, -2.46473104e-02,  6.86390772e-02,
#         -3.56159210e-02,  6.47558719e-02,  4.92868163e-02,
#         -6.31355420e-02, -5.60103282e-02, -4.72414568e-02,
#         -9.81409755e-03,  3.59761193e-02,  7.56186917e-02,
#          4.10142541e-02,  6.51928708e-02,  1.23051487e-01,
#          1.34600443e-03, -4.19883057e-02,  1.54162794e-02,
#         -1.00162067e-01, -5.18786646e-02, -8.33146423e-02,
#          6.79359287e-02,  4.22359593e-02, -8.93923827e-03,
#         -4.12749723e-02, -2.67390534e-02, -7.68720582e-02,
#          1.46500096e-01,  3.16821150e-02, -3.74349691e-02,
#         -1.43958852e-02, -5.23214899e-02, -5.07384129e-02,
#          6.42942488e-02,  1.33028831e-02, -5.43154106e-02,
#         -8.53605643e-02,  4.19928767e-02, -7.26163089e-02,
#         -3.69376019e-02, -7.27878138e-02,  1.67824342e-04,
#          6.10316806e-02,  2.67844144e-02, -9.22555011e-03,
#         -2.74230260e-03, -1.08648263e-01,  1.17344558e-01,
#         -1.22521281e-01, -4.28446867e-02,  5.17967977e-02,
#         -8.77298489e-02, -1.01252742e-01,  7.42843375e-03,
#         -1.21106459e-02,  4.88741659e-02,  7.56029785e-02,
#         -6.33065552e-02, -3.96228358e-02, -2.07476858e-02,
#         -5.70765920e-02,  5.96529208e-02,  2.59266421e-02,
#          5.70972376e-02,  8.87295790e-03, -3.08757871e-02,
#          2.49774032e-03,  1.97751466e-02, -2.27027666e-02,
#          2.57061105e-02, -1.28854081e-01, -7.92072117e-02]], dtype=float32)

# %%
results = semantic_search("space shuttle launch mission")
print(results)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 results = semantic_search("space shuttle launch mission")
#       2 print(results)
#
# Cell In[10], line 17, in semantic_search(query, k)
#      14     return cached
#      16 # FAISS search
# ---> 17 distances, indices = index.search(
#      18     np.array([query_embedding]), k
#      19 )
#      21 results = []
#      23 for i in indices[0]:
#
# NameError: name 'index' is not defined

# %%
print(df.shape)
df.head()
# Out:
# (19997, 2)
#                                                 text     category
# 0  Xref: cantaloupe.srv.cs.cmu.edu alt.atheism:49...  alt.atheism
# 1  Xref: cantaloupe.srv.cs.cmu.edu alt.atheism:51...  alt.atheism
# 2  Newsgroups: alt.atheism\nPath: cantaloupe.srv....  alt.atheism
# 3  Xref: cantaloupe.srv.cs.cmu.edu alt.atheism:51...  alt.atheism
# 4  Xref: cantaloupe.srv.cs.cmu.edu alt.atheism:51...  alt.atheism

# %%
model.encode(["hello world"])
# Out:
# array([[-3.44772041e-02,  3.10232397e-02,  6.73496863e-03,
#          2.61089690e-02, -3.93619612e-02, -1.60302460e-01,
#          6.69239312e-02, -6.44147955e-03, -4.74505574e-02,
#          1.47589119e-02,  7.08753690e-02,  5.55275641e-02,
#          1.91933755e-02, -2.62513272e-02, -1.01095000e-02,
#         -2.69405413e-02,  2.23074704e-02, -2.22266559e-02,
#         -1.49692699e-01, -1.74930841e-02,  7.67624797e-03,
#          5.43522798e-02,  3.25447368e-03,  3.17259766e-02,
#         -8.46213549e-02, -2.94059906e-02,  5.15956245e-02,
#          4.81240302e-02, -3.31479218e-03, -5.82792051e-02,
#          4.19693030e-02,  2.22106855e-02,  1.28188848e-01,
#         -2.23389659e-02, -1.16563011e-02,  6.29283339e-02,
#         -3.28762829e-02, -9.12260562e-02, -3.11753899e-02,
#          5.26995622e-02,  4.70348559e-02, -8.42030272e-02,
#         -3.00562084e-02, -2.07447819e-02,  9.51781124e-03,
#         -3.72180226e-03,  7.34334765e-03,  3.93243358e-02,
#          9.32740942e-02, -3.78861465e-03, -5.27421273e-02,
#         -5.80582172e-02, -6.86439546e-03,  5.28320158e-03,
#          8.28929767e-02,  1.93627197e-02,  6.28447579e-03,
#         -1.03307618e-02,  9.03236400e-03, -3.76836807e-02,
#         -4.52060923e-02,  2.40163747e-02, -6.94418000e-03,
#          1.34915914e-02,  1.00054979e-01, -7.16838986e-02,
#         -2.16950327e-02,  3.16185318e-02, -5.16346544e-02,
#         -8.22477415e-02, -6.56933337e-02, -9.89541225e-03,
#          5.81640890e-03,  7.35545754e-02, -3.40503044e-02,
#          2.48860680e-02,  1.44880479e-02,  2.64574029e-02,
#          9.65677015e-03,  3.02172918e-02,  5.28040081e-02,
#         -7.53598958e-02,  9.89719853e-03,  2.98368782e-02,
#          1.75555926e-02,  2.30919998e-02,  1.93390297e-03,
#          1.40016479e-03, -4.71759848e-02, -1.11944070e-02,
#         -1.14201397e-01, -1.98120363e-02,  4.02662419e-02,
